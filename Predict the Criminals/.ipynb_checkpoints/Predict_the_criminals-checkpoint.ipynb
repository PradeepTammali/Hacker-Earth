# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
import os

# %% [markdown]
# # Feature selection By manual preprocessing

# %%
train_path = os.getcwd() + '/criminal_train.csv'
test_path = os.getcwd() + '/criminal_test.csv'

# %%
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
data = train

# %%
data.describe()
# Out:
#               PERID       IFATHER      NRCH17_2      IRHHSIZ2      IIHHSIZ2  \
# count  4.571800e+04  45718.000000  45718.000000  45718.000000  45718.000000
# mean   5.445446e+07      3.355549      0.476486      3.426375      1.001706
# std    2.553911e+07      1.176651      0.888472      1.427420      0.061314
# min    1.000222e+07     -1.000000     -1.000000     -1.000000     -1.000000
# 25%    3.233189e+07      4.000000      0.000000      2.000000      1.000000
# 50%    5.411043e+07      4.000000      0.000000      3.000000      1.000000
# 75%    7.612731e+07      4.000000      1.000000      4.000000      1.000000
# max    9.999956e+07      4.000000      3.000000      6.000000      3.000000
#
#            IRKI17_2      IIKI17_2      IRHH65_2      IIHH65_2      PRXRETRY  \
# count  45718.000000  45718.000000  45718.000000  45718.000000  45718.000000
# mean       2.084124      1.007437      1.162606      1.011024     97.394943
# std        1.102988      0.123162      0.469029      0.146444     12.355156
# min       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 25%        1.000000      1.000000      1.000000      1.000000     99.000000
# 50%        2.000000      1.000000      1.000000      1.000000     99.000000
# 75%        3.000000      1.000000      1.000000      1.000000     99.000000
# max        4.000000      3.000000      3.000000      3.000000     99.000000
#
#            ...            TOOLONG      TROUBUND        PDEN10       COUTYP2  \
# count      ...       45718.000000  45718.000000  45718.000000  45718.000000
# mean       ...           2.219410      2.234940      1.646135      1.764666
# std        ...           5.295784      5.293651      0.618403      0.771411
# min        ...          -1.000000     -1.000000     -1.000000     -1.000000
# 25%        ...           2.000000      2.000000      1.000000      1.000000
# 50%        ...           2.000000      2.000000      2.000000      2.000000
# 75%        ...           2.000000      2.000000      2.000000      2.000000
# max        ...          98.000000     98.000000      3.000000      3.000000
#
#            MAIIN102      AIIND102       ANALWT_C         VESTR         VEREP  \
# count  45718.000000  45718.000000   45718.000000  45718.000000  45718.000000
# mean       1.978936      1.978739    4692.661179  40023.739118      1.493854
# std        0.144510      0.145161    5724.659486    265.140430      0.500230
# min       -1.000000     -1.000000      -1.000000     -1.000000     -1.000000
# 25%        2.000000      2.000000    1252.396472  40013.000000      1.000000
# 50%        2.000000      2.000000    2719.335160  40025.000000      1.000000
# 75%        2.000000      2.000000    5765.810794  40039.000000      2.000000
# max        2.000000      2.000000  109100.623000  40050.000000      2.000000
#
#            Criminal
# count  45718.000000
# mean       0.069447
# std        0.254216
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 72 columns]

# %%
data.head()
# Out:
#       PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0  25095143        4         2         4         1         3         1
# 1  13005143        4         1         3         1         2         1
# 2  67415143        4         1         2         1         2         1
# 3  70925143        4         0         2         1         1         1
# 4  75235143        1         0         6         1         4         1
#
#    IRHH65_2  IIHH65_2  PRXRETRY    ...     TOOLONG  TROUBUND  PDEN10  COUTYP2  \
# 0         1         1        99    ...           1         2       1        1
# 1         1         1        99    ...           2         2       2        3
# 2         1         1        99    ...           2         2       2        3
# 3         1         1        99    ...           2         2       1        1
# 4         1         1        99    ...           2         2       2        2
#
#    MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP  Criminal
# 0         2         2  3884.805998  40026      1         0
# 1         2         2  1627.108106  40015      2         1
# 2         2         2  4344.957980  40024      1         0
# 3         2         2   792.521931  40027      1         0
# 4         2         2  1518.118526  40001      2         0
#
# [5 rows x 72 columns]

# %%
# Dividing datasets to input and output variables. 
y = data['Criminal']
X = data.drop(labels='Criminal',axis=1)

# %%
i = 0
for column in X.columns:
    i +=1
    print(i,column,'zero count',(data[column] == 0).sum(), 'count',(data[column]).count())
# Out:
# 1 PERID zero count 0 count 45718
# 2 IFATHER zero count 0 count 45718
# 3 NRCH17_2 zero count 33475 count 45718
# 4 IRHHSIZ2 zero count 0 count 45718
# 5 IIHHSIZ2 zero count 0 count 45718
# 6 IRKI17_2 zero count 0 count 45718
# 7 IIKI17_2 zero count 0 count 45718
# 8 IRHH65_2 zero count 0 count 45718
# 9 IIHH65_2 zero count 0 count 45718
# 10 PRXRETRY zero count 0 count 45718
# 11 PRXYDATA zero count 0 count 45718
# 12 MEDICARE zero count 0 count 45718
# 13 CAIDCHIP zero count 0 count 45718
# 14 CHAMPUS zero count 0 count 45718
# 15 PRVHLTIN zero count 0 count 45718
# 16 GRPHLTIN zero count 0 count 45718
# 17 HLTINNOS zero count 0 count 45718
# 18 HLCNOTYR zero count 0 count 45718
# 19 HLCNOTMO zero count 0 count 45718
# 20 HLCLAST zero count 0 count 45718
# 21 HLLOSRSN zero count 0 count 45718
# 22 HLNVCOST zero count 0 count 45718
# 23 HLNVOFFR zero count 0 count 45718
# 24 HLNVREF zero count 0 count 45718
# 25 HLNVNEED zero count 0 count 45718
# 26 HLNVSOR zero count 0 count 45718
# 27 IRMCDCHP zero count 0 count 45718
# 28 IIMCDCHP zero count 0 count 45718
# 29 IRMEDICR zero count 0 count 45718
# 30 IIMEDICR zero count 0 count 45718
# 31 IRCHMPUS zero count 0 count 45718
# 32 IICHMPUS zero count 0 count 45718
# 33 IRPRVHLT zero count 0 count 45718
# 34 IIPRVHLT zero count 0 count 45718
# 35 IROTHHLT zero count 0 count 45718
# 36 IIOTHHLT zero count 0 count 45718
# 37 HLCALLFG zero count 0 count 45718
# 38 HLCALL99 zero count 0 count 45718
# 39 ANYHLTI2 zero count 0 count 45718
# 40 IRINSUR4 zero count 0 count 45718
# 41 IIINSUR4 zero count 0 count 45718
# 42 OTHINS zero count 0 count 45718
# 43 CELLNOTCL zero count 0 count 45718
# 44 CELLWRKNG zero count 0 count 45718
# 45 IRFAMSOC zero count 0 count 45718
# 46 IIFAMSOC zero count 0 count 45718
# 47 IRFAMSSI zero count 0 count 45718
# 48 IIFAMSSI zero count 0 count 45718
# 49 IRFSTAMP zero count 0 count 45718
# 50 IIFSTAMP zero count 0 count 45718
# 51 IRFAMPMT zero count 0 count 45718
# 52 IIFAMPMT zero count 0 count 45718
# 53 IRFAMSVC zero count 0 count 45718
# 54 IIFAMSVC zero count 0 count 45718
# 55 IRWELMOS zero count 0 count 45718
# 56 IIWELMOS zero count 0 count 45718
# 57 IRPINC3 zero count 0 count 45718
# 58 IRFAMIN3 zero count 0 count 45718
# 59 IIPINC3 zero count 0 count 45718
# 60 IIFAMIN3 zero count 0 count 45718
# 61 GOVTPROG zero count 0 count 45718
# 62 POVERTY3 zero count 0 count 45718
# 63 TOOLONG zero count 0 count 45718
# 64 TROUBUND zero count 0 count 45718
# 65 PDEN10 zero count 0 count 45718
# 66 COUTYP2 zero count 0 count 45718
# 67 MAIIN102 zero count 0 count 45718
# 68 AIIND102 zero count 0 count 45718
# 69 ANALWT_C zero count 0 count 45718
# 70 VESTR zero count 0 count 45718
# 71 VEREP zero count 0 count 45718

# %%
if 'NRCH17_2' in X.columns:
    del X['NRCH17_2']
    
if 'PERID' in X.columns:
    del X['PERID']
    
if 'ANALWT_C' in X.columns:
    del X['ANALWT_C']
X.head()
# Out:
#    IFATHER  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  IIHH65_2  \
# 0        4         4         1         3         1         1         1
# 1        4         3         1         2         1         1         1
# 2        4         2         1         2         1         1         1
# 3        4         2         1         1         1         1         1
# 4        1         6         1         4         1         1         1
#
#    PRXRETRY  PRXYDATA  MEDICARE  ...    GOVTPROG  POVERTY3  TOOLONG  TROUBUND  \
# 0        99        99         2  ...           1         2        1         2
# 1        99        99         2  ...           1         1        2         2
# 2        99        99         2  ...           1         1        2         2
# 3        99        99         2  ...           2         3        2         2
# 4        99         1         2  ...           1         1        2         2
#
#    PDEN10  COUTYP2  MAIIN102  AIIND102  VESTR  VEREP
# 0       1        1         2         2  40026      1
# 1       2        3         2         2  40015      2
# 2       2        3         2         2  40024      1
# 3       1        1         2         2  40027      1
# 4       2        2         2         2  40001      2
#
# [5 rows x 68 columns]

# %%
for column in X.columns:
    print(column, 'distint', len(X[column].unique()), X[column].unique())
# Out:
# IFATHER distint 5 [ 4  1  2  3 -1]
# IRHHSIZ2 distint 7 [ 4  3  2  6  1  5 -1]
# IIHHSIZ2 distint 3 [ 1  3 -1]
# IRKI17_2 distint 5 [ 3  2  1  4 -1]
# IIKI17_2 distint 3 [ 1  3 -1]
# IRHH65_2 distint 4 [ 1  2  3 -1]
# IIHH65_2 distint 4 [ 1  3  2 -1]
# PRXRETRY distint 6 [99  2 98 94 97 -1]
# PRXYDATA distint 7 [99  1 98 94  2 97 -1]
# MEDICARE distint 7 [ 2  1 94 97 98 85 -1]
# CAIDCHIP distint 7 [ 1  2 85 97 94 98 -1]
# CHAMPUS distint 7 [ 2  1 94 97 98 85 -1]
# PRVHLTIN distint 7 [ 2  1 94 97 98 85 -1]
# GRPHLTIN distint 8 [99  1  2 98 97 94 85 -1]
# HLTINNOS distint 7 [99  2  1 94 97 98 -1]
# HLCNOTYR distint 8 [ 2 99  1 98 97 85 94 -1]
# HLCNOTMO distint 18 [99  2  3  1  6  8  4 98  5 97 12 11  9 10 85  7 94 -1]
# HLCLAST distint 10 [99  1  5  2  4  3 98 97 94 -1]
# HLLOSRSN distint 18 [99  1  2 12  4  5 11 98  3  9 97  6 10  7  8 94 85 -1]
# HLNVCOST distint 7 [99  1 98  6 97 94 -1]
# HLNVOFFR distint 7 [99  6 98 97  1 94 -1]
# HLNVREF distint 7 [99  6 98 97  1 94 -1]
# HLNVNEED distint 7 [99  6 98  1 97 94 -1]
# HLNVSOR distint 7 [99  6 98 97  1 94 -1]
# IRMCDCHP distint 3 [ 1  2 -1]
# IIMCDCHP distint 3 [ 1  3 -1]
# IRMEDICR distint 3 [ 2  1 -1]
# IIMEDICR distint 3 [ 1  3 -1]
# IRCHMPUS distint 3 [ 2  1 -1]
# IICHMPUS distint 3 [ 1  3 -1]
# IRPRVHLT distint 3 [ 2  1 -1]
# IIPRVHLT distint 3 [ 1  3 -1]
# IROTHHLT distint 4 [99  2  1 -1]
# IIOTHHLT distint 4 [ 9  1  3 -1]
# HLCALLFG distint 3 [98  1 -1]
# HLCALL99 distint 3 [98  1 -1]
# ANYHLTI2 distint 6 [ 1  2 94 97 98 -1]
# IRINSUR4 distint 3 [ 1  2 -1]
# IIINSUR4 distint 3 [ 1  3 -1]
# OTHINS distint 3 [ 2  1 -1]
# CELLNOTCL distint 7 [ 1  2 97 94 98 85 -1]
# CELLWRKNG distint 7 [ 1  2 97 94 98 85 -1]
# IRFAMSOC distint 3 [ 2  1 -1]
# IIFAMSOC distint 3 [ 1  3 -1]
# IRFAMSSI distint 3 [ 2  1 -1]
# IIFAMSSI distint 3 [ 1  3 -1]
# IRFSTAMP distint 3 [ 1  2 -1]
# IIFSTAMP distint 3 [ 1  3 -1]
# IRFAMPMT distint 3 [ 2  1 -1]
# IIFAMPMT distint 3 [ 1  3 -1]
# IRFAMSVC distint 3 [ 2  1 -1]
# IIFAMSVC distint 3 [ 1  3 -1]
# IRWELMOS distint 14 [99  1  2 12  4 10  8  5  3  6  7 11  9 -1]
# IIWELMOS distint 4 [ 9  1  3 -1]
# IRPINC3 distint 8 [ 1  2  7  6  3  5  4 -1]
# IRFAMIN3 distint 8 [ 4  1  2  7  3  6  5 -1]
# IIPINC3 distint 3 [ 1  3 -1]
# IIFAMIN3 distint 3 [ 1  3 -1]
# GOVTPROG distint 3 [ 1  2 -1]
# POVERTY3 distint 4 [ 2  1  3 -1]
# TOOLONG distint 4 [ 1  2 98 -1]
# TROUBUND distint 4 [ 2 98  1 -1]
# PDEN10 distint 4 [ 1  2  3 -1]
# COUTYP2 distint 4 [ 1  3  2 -1]
# MAIIN102 distint 3 [ 2  1 -1]
# AIIND102 distint 3 [ 2  1 -1]
# VESTR distint 51 [40026 40015 40024 40027 40001 40035 40043 40006 40021 40044 40025 40042
#  40020 40004 40023 40033 40036 40028 40008 40007 40010 40012 40046 40016
#  40022 40038 40019 40034 40011 40018 40030 40003 40048 40013 40029 40017
#  40050 40009 40005 40041 40002 40032 40039 40047 40049 40014 40040 40037
#  40045 40031    -1]
# VEREP distint 3 [ 1  2 -1]

# %%
for i in X.columns:
    y_data = []
    for uniq in X[i].unique():
        y_data.append((X[i] == uniq).sum())
    x_data=list(X[i].unique())
    x_axis = i+' distinct values'
    y_axis = i+' count'
    bar_df = pd.DataFrame({x_axis:list(x_data), y_axis:list(y_data)})
    bar_df.plot(x_axis, y_axis, kind='bar', color='r')
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
column_list = []
column_list.append('IRHHSIZ2')
column_list.append('IRKI17_2')
column_list.append('IRPINC3')
column_list.append('IRFAMIN3')
column_list.append('POVERTY3')
column_list.append('PDEN10')
column_list.append('COUTYP2')
column_list.append('VESTR')
column_list.append('VEREP')

# %%
X.shape, y.shape
# Out:
# ((45718, 68), (45718,))

# %%
column = list(X.columns)
# mark zero values as missing or NaN
X[column] = X[column].replace(0, np.NAN)
# count the number of NaN values in each column
print(X.isnull().sum())
# Out:
# IFATHER      0
# IRHHSIZ2     0
# IIHHSIZ2     0
# IRKI17_2     0
# IIKI17_2     0
# IRHH65_2     0
# IIHH65_2     0
# PRXRETRY     0
# PRXYDATA     0
# MEDICARE     0
# CAIDCHIP     0
# CHAMPUS      0
# PRVHLTIN     0
# GRPHLTIN     0
# HLTINNOS     0
# HLCNOTYR     0
# HLCNOTMO     0
# HLCLAST      0
# HLLOSRSN     0
# HLNVCOST     0
# HLNVOFFR     0
# HLNVREF      0
# HLNVNEED     0
# HLNVSOR      0
# IRMCDCHP     0
# IIMCDCHP     0
# IRMEDICR     0
# IIMEDICR     0
# IRCHMPUS     0
# IICHMPUS     0
#             ..
# IIINSUR4     0
# OTHINS       0
# CELLNOTCL    0
# CELLWRKNG    0
# IRFAMSOC     0
# IIFAMSOC     0
# IRFAMSSI     0
# IIFAMSSI     0
# IRFSTAMP     0
# IIFSTAMP     0
# IRFAMPMT     0
# IIFAMPMT     0
# IRFAMSVC     0
# IIFAMSVC     0
# IRWELMOS     0
# IIWELMOS     0
# IRPINC3      0
# IRFAMIN3     0
# IIPINC3      0
# IIFAMIN3     0
# GOVTPROG     0
# POVERTY3     0
# TOOLONG      0
# TROUBUND     0
# PDEN10       0
# COUTYP2      0
# MAIIN102     0
# AIIND102     0
# VESTR        0
# VEREP        0
# Length: 68, dtype: int64

# %%
column_list
# Out:
# ['IRHHSIZ2',
#  'IRKI17_2',
#  'IRPINC3',
#  'IRFAMIN3',
#  'POVERTY3',
#  'PDEN10',
#  'COUTYP2',
#  'VESTR',
#  'VEREP']

# %%
for i in X.columns:
    if i not in column_list:
        del X[i]

# %%
X.head()
# Out:
#    IRHHSIZ2  IRKI17_2  IRPINC3  IRFAMIN3  POVERTY3  PDEN10  COUTYP2  VESTR  \
# 0         4         3        1         4         2       1        1  40026
# 1         3         2        1         1         1       2        3  40015
# 2         2         2        2         2         1       2        3  40024
# 3         2         1        7         7         3       1        1  40027
# 4         6         4        1         2         1       2        2  40001
#
#    VEREP
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2

# %%
from sklearn.model_selection import train_test_split

#diving input training dataset into train and valdiation datasets
X_train, X_val = train_test_split(X,test_size=0.1,train_size=0.9)

#diving output training dataset into train and valdiation datasets
y_train, y_val = train_test_split(y,test_size=0.1,train_size=0.9)

X_train = X
y_train = y

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = model.predict(X_val)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_val, y_pred)
confusion_matrix
# Out:
# array([[4221,    1],
#        [ 350,    0]])

# %%
model.score(X_val, y_val), model.score(X_train, y_train)
# Out:
# (0.9232283464566929, 0.9305087711623431)

# %% [markdown]
# # Post Processing

# %%
X_test = test

# %%
if 'NRCH17_2' in X_test.columns:
    del X_test['NRCH17_2']
    
if 'PERID' in X_test.columns:
    X_perid = X_test['PERID']
    del X_test['PERID']
    
if 'ANALWT_C' in X_test.columns:
    del X_test['ANALWT_C']

column = list(X_test.columns)
# mark zero values as missing or NaN
X_test[column] = X_test[column].replace(0, np.NAN)
# count the number of NaN values in each column
print(X_test.isnull().sum())
# Out:
# IFATHER      0
# IRHHSIZ2     0
# IIHHSIZ2     0
# IRKI17_2     0
# IIKI17_2     0
# IRHH65_2     0
# IIHH65_2     0
# PRXRETRY     0
# PRXYDATA     0
# MEDICARE     0
# CAIDCHIP     0
# CHAMPUS      0
# PRVHLTIN     0
# GRPHLTIN     0
# HLTINNOS     0
# HLCNOTYR     0
# HLCNOTMO     0
# HLCLAST      0
# HLLOSRSN     0
# HLNVCOST     0
# HLNVOFFR     0
# HLNVREF      0
# HLNVNEED     0
# HLNVSOR      0
# IRMCDCHP     0
# IIMCDCHP     0
# IRMEDICR     0
# IIMEDICR     0
# IRCHMPUS     0
# IICHMPUS     0
#             ..
# IIINSUR4     0
# OTHINS       0
# CELLNOTCL    0
# CELLWRKNG    0
# IRFAMSOC     0
# IIFAMSOC     0
# IRFAMSSI     0
# IIFAMSSI     0
# IRFSTAMP     0
# IIFSTAMP     0
# IRFAMPMT     0
# IIFAMPMT     0
# IRFAMSVC     0
# IIFAMSVC     0
# IRWELMOS     0
# IIWELMOS     0
# IRPINC3      0
# IRFAMIN3     0
# IIPINC3      0
# IIFAMIN3     0
# GOVTPROG     0
# POVERTY3     0
# TOOLONG      0
# TROUBUND     0
# PDEN10       0
# COUTYP2      0
# MAIIN102     0
# AIIND102     0
# VESTR        0
# VEREP        0
# Length: 68, dtype: int64

# %%
for i in X_test.columns:
    if i not in column_list:
        del X_test[i]

# %%
y_test_pred = model.predict(X_test)

# %%
dataframe_manual = pd.DataFrame(X_perid)

# %%
dataframe_manual['Criminal'] = y_test_pred

# %%
dataframe_manual.to_csv('submission_27-03-2018_manual.csv', index=False)

# %% [markdown]
# # Correlation Matrix

# %%
criminal = data[data['Criminal'].isin([1])]
non_criminal = data[data['Criminal'].isin([0])]
fig, ax = plt.subplots(figsize=(6,4))  
ax.scatter(criminal['VESTR'],criminal['ANALWT_C'], s=50, c='b', marker='o', label='criminal')  
ax.scatter(non_criminal['VESTR'],non_criminal['ANALWT_C'], s=50, c='r', marker='x', label='non criminal')  
ax.legend()   
ax.set_xlabel('criminal')  
ax.set_ylabel('non_criminal')
# Out:
# Text(0,0.5,'non_criminal')

# %%
data_corr = X.corr()
mask = np.zeros_like(data_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
import seaborn as sns
sns.set(style="white")

# %%
fig, ax = plt.subplots(figsize=(20,15))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(data_corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Feature selection by factor analysis and eigen values

# %%
from sklearn import decomposition, preprocessing
X = data

# %%
X = X[~np.isnan(X).any(axis=1)]
X_normal = preprocessing.scale(X) # Normalization
fa = decomposition.FactorAnalysis(n_components=1)
fa.fit(X_normal)
# Out:
# FactorAnalysis(copy=True, iterated_power=3, max_iter=1000, n_components=1,
#         noise_variance_init=None, random_state=0, svd_method='randomized',
#         tol=0.01)

# %%
print(fa.components_) # Factor loadings
# Out:
# [[-9.67458673e-04  1.24438186e-01  6.34920545e-02  4.83913130e-02
#    1.74857013e-02 -8.28585926e-03  2.96906504e-02 -5.44095617e-02
#    2.02673943e-02 -4.51676825e-03  1.04279972e-01  2.49140668e-02
#    2.40701834e-02  9.60396374e-03  4.12088242e-02  4.44806626e-01
#   -8.71215854e-01  9.60597540e-01  9.27839605e-02 -9.86422486e-01
#   -8.72405592e-01 -4.19252530e-01 -4.19300394e-01 -4.19352512e-01
#   -4.19283639e-01 -4.19300951e-01  1.80463339e-01  1.61874352e-02
#    1.06781331e-01  2.14527290e-02  7.01555067e-02  8.27215478e-03
#    4.46501744e-01  1.42843345e-02 -8.74812361e-01 -8.71539465e-01
#    1.00145423e-02  1.00145423e-02  8.43863931e-02  9.90775134e-01
#    5.19573882e-02  1.17931844e-01  2.46460297e-02  1.06753482e-02
#    4.64972101e-02  1.67243245e-02  8.55849193e-03  2.29167868e-02
#   -8.08565058e-02  1.78617211e-02  3.26409265e-03  1.56663435e-02
#   -7.82552795e-03  1.20026819e-02 -9.25468390e-03 -1.21492849e-02
#   -1.06027302e-01 -1.99791395e-01  9.19365686e-03  4.69601225e-02
#   -7.35526324e-02 -1.76903152e-01 -1.00884513e-03 -4.40750549e-04
#    3.63804543e-03  9.83089869e-03 -1.04690299e-02 -9.06605024e-03
#   -1.49114148e-02  1.19621661e-02  2.51816063e-03 -9.20283730e-02]]

# %%
import numpy.linalg as linalg
B = np.array(X)

# %% [markdown]
# # Recursive Feature Elimination

# %%
from sklearn.model_selection import train_test_split

#diving input training dataset into train and valdiation datasets
X_train, X_val = train_test_split(X,test_size=0.1,train_size=0.9)

#diving output training dataset into train and valdiation datasets
y_train, y_val = train_test_split(y,test_size=0.1,train_size=0.9)

# %%
X_train = X
y_train = y

# %%
# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
rfe = RFE(model, 12)
fit = rfe.fit(X, y)
print("Num Features: ", fit.n_features_) 
print("Selected Features: ", fit.support_)
print("Feature Ranking: ", fit.ranking_)
# Out:
# Num Features:  12
# Selected Features:  [ True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False  True  True False False False  True  True False  True False False
#  False  True  True  True False False  True False False  True False False
#  False False False False False False False  True False False False False
#  False False False False False False False False]
# Feature Ranking:  [ 1 17 50  6 20  9 15 56 41 49 55 28 24 25 26 32 46 31 52 54 44 43 47 53
#  21  1  1 27 22  8  1  1 30  1 29 38 45  1  1  1 40 48  1 14 37  1 12  2
#  39 42 33  3 51 34  4  1 11 10 13  5 36 35 18 19 23  7 57 16]

# %%
columns = X_train.columns

# %%
# Removing un important features from training set
for i in range(len(columns)):
    if not fit.support_[i]:
        if columns[i] in X_train.columns:
            del X_train[columns[i]]
        if columns[i] in X_val.columns:
            del X_val[columns[i]]

# %%
X_train.columns
# Out:
# Index(['IFATHER', 'IIMCDCHP', 'IRMEDICR', 'IRPRVHLT', 'IIPRVHLT', 'IIOTHHLT',
#        'IRINSUR4', 'IIINSUR4', 'OTHINS', 'IRFAMSOC', 'IIFAMSSI', 'IRFAMIN3'],
#       dtype='object')

# %%
X_val.shape, X_train.shape, y_val.shape, y_train.shape
# Out:
# ((4572, 12), (45718, 12), (4572,), (45718,))

# %%
LogReg = LogisticRegression()
LogReg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = LogReg.predict(X_val)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_val, y_pred)
confusion_matrix
# Out:
# array([[4124,  109],
#        [ 332,    7]])

# %%
LogReg.score(X_val, y_val), LogReg.score(X_train, y_train)
# Out:
# (0.9035433070866141, 0.9391268209457981)

# %% [markdown]
# # Post Processing

# %%
if 'Criminal' in test.columns:
    X_test = test.drop(labels='Criminal',axis=1)
else:
    X_test = test
X_test.head()
# Out:
#       PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0  66583679        4         0         4         1         2         1
# 1  35494679        4         0         4         1         1         1
# 2  79424679        2         0         3         1         2         1
# 3  11744679        4         0         6         1         2         1
# 4  31554679        1         0         4         1         3         1
#
#    IRHH65_2  IIHH65_2  PRXRETRY  ...    POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# 0         1         1        99  ...           2        2         2       1
# 1         1         1        99  ...           3        2         2       1
# 2         1         1        99  ...           1        2         2       2
# 3         1         1        99  ...           3        2         2       1
# 4         1         1        99  ...           3        2         1       1
#
#    COUTYP2  MAIIN102  AIIND102      ANALWT_C  VESTR  VEREP
# 0        1         2         2  16346.795400  40020      1
# 1        1         2         2   3008.863906  40044      2
# 2        2         2         2    266.952503  40040      2
# 3        1         2         2   5386.928199  40017      1
# 4        1         2         2    173.489895  40017      1
#
# [5 rows x 71 columns]

# %%
if 'NRCH17_2' in X_test.columns:
    del X_test['NRCH17_2']
    
if 'PERID' in X_test.columns:
    del X_test['PERID']
    
if 'ANALWT_C' in X_test.columns:
    del X_test['ANALWT_C']
X_test.head()
# Out:
#    IFATHER  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  IIHH65_2  \
# 0        4         4         1         2         1         1         1
# 1        4         4         1         1         1         1         1
# 2        2         3         1         2         1         1         1
# 3        4         6         1         2         1         1         1
# 4        1         4         1         3         1         1         1
#
#    PRXRETRY  PRXYDATA  MEDICARE  ...    GOVTPROG  POVERTY3  TOOLONG  TROUBUND  \
# 0        99        99         2  ...           2         2        2         2
# 1        99        99         2  ...           2         3        2         2
# 2        99         1         2  ...           1         1        2         2
# 3        99        99         2  ...           2         3        2         2
# 4        99         1         2  ...           2         3        2         1
#
#    PDEN10  COUTYP2  MAIIN102  AIIND102  VESTR  VEREP
# 0       1        1         2         2  40020      1
# 1       1        1         2         2  40044      2
# 2       2        2         2         2  40040      2
# 3       1        1         2         2  40017      1
# 4       1        1         2         2  40017      1
#
# [5 rows x 68 columns]

# %%
column = list(X_test.columns)
# mark zero values as missing or NaN
X_test[column] = X_test[column].replace(0, np.NAN)
# count the number of NaN values in each column
print(X_test.isnull().sum())
# Out:
# IFATHER      0
# IRHHSIZ2     0
# IIHHSIZ2     0
# IRKI17_2     0
# IIKI17_2     0
# IRHH65_2     0
# IIHH65_2     0
# PRXRETRY     0
# PRXYDATA     0
# MEDICARE     0
# CAIDCHIP     0
# CHAMPUS      0
# PRVHLTIN     0
# GRPHLTIN     0
# HLTINNOS     0
# HLCNOTYR     0
# HLCNOTMO     0
# HLCLAST      0
# HLLOSRSN     0
# HLNVCOST     0
# HLNVOFFR     0
# HLNVREF      0
# HLNVNEED     0
# HLNVSOR      0
# IRMCDCHP     0
# IIMCDCHP     0
# IRMEDICR     0
# IIMEDICR     0
# IRCHMPUS     0
# IICHMPUS     0
#             ..
# IIINSUR4     0
# OTHINS       0
# CELLNOTCL    0
# CELLWRKNG    0
# IRFAMSOC     0
# IIFAMSOC     0
# IRFAMSSI     0
# IIFAMSSI     0
# IRFSTAMP     0
# IIFSTAMP     0
# IRFAMPMT     0
# IIFAMPMT     0
# IRFAMSVC     0
# IIFAMSVC     0
# IRWELMOS     0
# IIWELMOS     0
# IRPINC3      0
# IRFAMIN3     0
# IIPINC3      0
# IIFAMIN3     0
# GOVTPROG     0
# POVERTY3     0
# TOOLONG      0
# TROUBUND     0
# PDEN10       0
# COUTYP2      0
# MAIIN102     0
# AIIND102     0
# VESTR        0
# VEREP        0
# Length: 68, dtype: int64

# %%
columns = X_test.columns
# Removing un important features from training set
for i in range(len(columns)):
    if not fit.support_[i]:
        if columns[i] in X_test.columns:
            del X_test[columns[i]]

# %%
X_test.columns
# Out:
# Index(['IFATHER', 'IIMCDCHP', 'IRMEDICR', 'IRPRVHLT', 'IIPRVHLT', 'IIOTHHLT',
#        'IRINSUR4', 'IIINSUR4', 'OTHINS', 'IRFAMSOC', 'IIFAMSSI', 'IRFAMIN3'],
#       dtype='object')

# %%
y_test_pred = LogReg.predict(X_test)

# %%
LogReg.score(X_val, y_val), LogReg.score(X_train, y_train)
# Out:
# (0.9035433070866141, 0.9391268209457981)

# %%
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
