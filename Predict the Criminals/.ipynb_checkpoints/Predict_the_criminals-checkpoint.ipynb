# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
import os

# %%
path = os.getcwd() + '/criminal_train.csv'

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#       PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0  25095143        4         2         4         1         3         1
# 1  13005143        4         1         3         1         2         1
# 2  67415143        4         1         2         1         2         1
# 3  70925143        4         0         2         1         1         1
# 4  75235143        1         0         6         1         4         1
#
#    IRHH65_2  IIHH65_2  PRXRETRY    ...     TOOLONG  TROUBUND  PDEN10  COUTYP2  \
# 0         1         1        99    ...           1         2       1        1
# 1         1         1        99    ...           2         2       2        3
# 2         1         1        99    ...           2         2       2        3
# 3         1         1        99    ...           2         2       1        1
# 4         1         1        99    ...           2         2       2        2
#
#    MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP  Criminal
# 0         2         2  3884.805998  40026      1         0
# 1         2         2  1627.108106  40015      2         1
# 2         2         2  4344.957980  40024      1         0
# 3         2         2   792.521931  40027      1         0
# 4         2         2  1518.118526  40001      2         0
#
# [5 rows x 72 columns]

# %%
criminal = data[data['Criminal'].isin([1])]
non_criminal = data[data['Criminal'].isin([0])]

# %%
fig, ax = plt.subplots(figsize=(12,8))  
ax.scatter(criminal['VESTR'],criminal['ANALWT_C'], s=50, c='b', marker='o', label='criminal')  
ax.scatter(non_criminal['VESTR'],non_criminal['ANALWT_C'], s=50, c='r', marker='x', label='non criminal')  
ax.legend()  
ax.set_xlabel('criminal')  
ax.set_ylabel('non_criminal')
# Out:
# Text(0,0.5,'non_criminal')

# %%
data_corr = data.corr()
mask = np.zeros_like(data_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
import seaborn as sns
sns.set(style="white")

# %%
fig, ax = plt.subplots(figsize=(20,15))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(data_corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Dividing datasets to input and output variables. 
y = data['Criminal']
#del(data['Criminal'])
X = data.drop(labels='Criminal', axis=1)
X.shape
# Out:
# (45718, 71)

# %%
from sklearn import decomposition, preprocessing

# %%
X = X[~np.isnan(X).any(axis=1)]
X_normal = preprocessing.scale(X) # Normalization
preprocessing.scale?
fa = decomposition.FactorAnalysis(n_components=1)
fa.fit(X_normal)
# Out:
# FactorAnalysis(copy=True, iterated_power=3, max_iter=1000, n_components=1,
#         noise_variance_init=None, random_state=0, svd_method='randomized',
#         tol=0.01)

# %%
X.head()
#print(fa.components_) # Factor loadings
# Out:
#       PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0  25095143        4         2         4         1         3         1
# 1  13005143        4         1         3         1         2         1
# 2  67415143        4         1         2         1         2         1
# 3  70925143        4         0         2         1         1         1
# 4  75235143        1         0         6         1         4         1
#
#    IRHH65_2  IIHH65_2  PRXRETRY  ...    POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# 0         1         1        99  ...           2        1         2       1
# 1         1         1        99  ...           1        2         2       2
# 2         1         1        99  ...           1        2         2       2
# 3         1         1        99  ...           3        2         2       1
# 4         1         1        99  ...           1        2         2       2
#
#    COUTYP2  MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP
# 0        1         2         2  3884.805998  40026      1
# 1        3         2         2  1627.108106  40015      2
# 2        3         2         2  4344.957980  40024      1
# 3        1         2         2   792.521931  40027      1
# 4        2         2         2  1518.118526  40001      2
#
# [5 rows x 71 columns]

# %%
from sklearn.decomposition import PCA as sklearnPCA

# %%
sklearn_pca = sklearnPCA(n_components=2)

# %%
Y_sklearn = sklearn_pca.fit_transform(X)

# %%
Y_sklearn
# Out:
# array([[ -2.93593208e+07,  -8.33951505e+02],
#        [ -4.14493208e+07,  -3.10234480e+03],
#        [  1.29606792e+07,  -3.36148990e+02],
#        ...,
#        [ -2.28078479e+06,  -3.20487125e+03],
#        [ -2.51707848e+07,  -8.67917591e+02],
#        [  3.30292152e+07,   6.69458675e+03]])

# %%
traces = []

for name in X.columns:

    trace = Scatter(
        x=Y_sklearn[y==name,0],
        y=Y_sklearn[y==name,1],
        mode='markers',
        name=name,
        marker=Marker(
            size=12,
            line=Line(
                color='rgba(217, 217, 217, 0.14)',
                width=0.5),
            opacity=0.8))
    traces.append(trace)


data = Data(traces)
layout = Layout(xaxis=XAxis(title='PC1', showline=False),
                yaxis=YAxis(title='PC2', showline=False))
fig = Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-ccc4b9c0ce57> in <module>()
#       3 for name in X.columns:
#       4
# ----> 5     trace = Scatter(
#       6         x=Y_sklearn[y==name,0],
#       7         y=Y_sklearn[y==name,1],
#
# NameError: name 'Scatter' is not defined
